# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Burak Kasap**\
# Internal Auditor

# %% [markdown]
# *I am interested in Data Science because I like thinking analytically and factual. I also like making inferences and suggestions out of cleaned, organized, manipulated data through interesting visuals.*

# %% [markdown]
# ### The following code will run a simple math calculation and then it will display the result.

# %%
output = 1+1
print(output)
# Out:
# 2

# %% [markdown]
# Name | Age | Profession
# --- | --- | ---
# Burak | 27 | Internal Auditor
# James | 24 | Data Scientist
# Lorenzo | 30 | Data Engineer
#
#
# - Burak is an Internal Auditor
# - James is a Data Scientist
# - Lorenzo is a Data Engineer
#
#
#
#
# This is an horizontal
# ***
# separator
#
#
#
# 1. Num
# 2. Bered
# 3. List
#
# > A block quote
#
#
# __[Coursera](http://coursera.org)__
#
# <a href="http://coursera.org">Coursera</a>
